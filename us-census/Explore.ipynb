# %% [markdown]
# #### Setup: Python Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.feature import StringIndexer, VectorAssembler, OneHotEncoder
from pyspark.sql.functions import lit

# %matplotlib inline

# %% [markdown]
# # Business Understanding

# %% [markdown]
# In the context of an (supposedly quick) interview exercise to demonstrate some critical skills as a Data Scientist, the goal of this exercise is not to create the best or the purest model, but rather to describe the steps we’ll take to accomplish it and explain the places that may have been the most challenging.
#
# Let's find clear insights on the profiles of the people that make more than $50,000 / year.
# For example, which variables seem to be the most correlated with this phenomenon?

# %% [markdown]
# # Data Understanding

# %% [markdown]
# #### Data loading

# %% [markdown]
# * Import the learning and test files

# %%
# the meta data 
columnNames = [ w.replace(' ', '_') for w in [
    "age",
    "class of worker",
    "industry code",
    "occupation code",
    #"adjusted gross income",
    "education",
    "wage per hour",
    "enrolled in edu inst last wk",
    "marital status",
    "major industry code",
    "major occupation code",
    "race",
    "hispanic Origin",
    "sex",
    "member of a labor union",
    "reason for unemployment",
    "full or part time employment stat",
    "capital gains",
    "capital losses",
    "divdends from stocks",
    #"federal income tax liability",
    "tax filer status",
    "region of previous residence",
    "state of previous residence",
    "detailed household and family stat",
    "detailed household summary in household",
    "instance weight",
    "migration code-change in msa",
    "migration code-change in reg",
    "migration code-move within reg",
    "live in this house 1 year ago",
    "migration prev res in sunbelt",
    "num persons worked for employer",
    "family members under 18",
    #"total person earnings",
    "country of birth father",
    "country of birth mother",
    "country of birth self",
    "citizenship",
    "own business or self employed",
    "fill inc questionnaire for veteran's admin",
    "veterans benefits",
    "weeks worked in year",
    #"taxable income amount",
    "year",
    "total person income"
]]
targetColumn = "total_person_income"
lessThan50k = " - 50000."
print "Number of columns defined: " + str(len(columnNames))
train = pd.read_csv('us_census_full/census_income_learn.csv', header=None)
print "Number of columns in data frame: " + str(len(train.columns))
train.columns = columnNames
target = (train[targetColumn] != lessThan50k).astype(int)

train.head(1)
# Out:
# Number of columns defined: 42
# Number of columns in data frame: 42
#    age   class_of_worker  industry_code  occupation_code  \
# 0   73   Not in universe              0                0
#
#                education  wage_per_hour enrolled_in_edu_inst_last_wk  \
# 0   High school graduate              0              Not in universe
#
#   marital_status           major_industry_code major_occupation_code  \
# 0        Widowed   Not in universe or children       Not in universe
#
#           ...         country_of_birth_father country_of_birth_mother  \
# 0         ...                   United-States           United-States
#
#   country_of_birth_self                         citizenship  \
# 0         United-States   Native- Born in the United States
#
#   own_business_or_self_employed fill_inc_questionnaire_for_veteran's_admin  \
# 0                             0                            Not in universe
#
#    veterans_benefits  weeks_worked_in_year  year total_person_income
# 0                  2                     0    95            - 50000.
#
# [1 rows x 42 columns]

# %% [markdown]
# #### Simple Data audit

# %% [markdown]
# * Make a quick statistic based and univariate audit of the different columns’ content and produce the results in visual / graphic format.
# * This audit should describe the variable distribution, the % of missing values, the extreme values, and so on.

# %%
def describe(df):
    # FIXME: add better legends
    for i in df.columns:
        print "***************************************"
        print "Describing Column " + str(i) + ":" 
        numValues = pd.Series(df[i].values.ravel()).unique().size
        if df[i].dtype !=  np.object and numValues > 5:
            auditNumericalColumn(df, str(i))
        else:
            auditCategoricalColumn(df, str(i))

def auditNumericalColumn(df, columnName):
    col = df[columnName]
    print col.describe()
    fig = plt.figure()
    if col.dtype == np.int64:
        num_bins = pd.Series(col.values.ravel()).unique().size
    else:
        num_bins = 100
    data = [
        df[df[targetColumn] != lessThan50k][columnName].values,
        df[df[targetColumn] == lessThan50k][columnName].values
    ]
    f, axarr = plt.subplots(2, sharex=True)
    axarr[0].boxplot(data, vert = False, showmeans = True, whis = [2, 99])
    axarr[1].hist(data, num_bins, color = ['g','r'], stacked=True, alpha = 0.6)
    plt.title("Values Histogram of column:" + columnName)
    plt.xlabel("Values")
    plt.ylabel("count") 
    plt.show()
    
def auditCategoricalColumn(df, columnName):
    col = df[columnName]
    total = col.count()
    counts = pd.DataFrame(col.value_counts(), columns=["count"])
    counts["%"] = counts["count"] * 100.0 / total
    print counts
    col.value_counts().plot(kind="bar")
    plt.show()

# %%
describe(train)
# Out:
# ***************************************
# Describing Column age:
# count    199523.000000
# mean         34.494199
# std          22.310895
# min           0.000000
# 25%          15.000000
# 50%          33.000000
# 75%          50.000000
# max          90.000000
# Name: age, dtype: float64
# ***************************************
# Describing Column class_of_worker:
#                                   count          %
#  Not in universe                 100245  50.242328
#  Private                          72028  36.100099
#  Self-employed-not incorporated    8445   4.232595
#  Local government                  7784   3.901305
#  State government                  4227   2.118553
#  Self-employed-incorporated        3265   1.636403
#  Federal government                2925   1.465996
#  Never worked                       439   0.220025
#  Without pay                        165   0.082697
# ***************************************
# Describing Column industry_code:
# count    199523.000000
# mean         15.352320
# std          18.067129
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          33.000000
# max          51.000000
# Name: industry_code, dtype: float64
# ***************************************
# Describing Column occupation_code:
# count    199523.000000
# mean         11.306556
# std          14.454204
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          26.000000
# max          46.000000
# Name: occupation_code, dtype: float64
# ***************************************
# Describing Column education:
#                                          count          %
#  High school graduate                    48407  24.261363
#  Children                                47422  23.767686
#  Some college but no degree              27820  13.943255
#  Bachelors degree(BA AB BS)              19865   9.956246
#  7th and 8th grade                        8007   4.013071
#  10th grade                               7557   3.787533
#  11th grade                               6876   3.446219
#  Masters degree(MA MS MEng MEd MSW MBA)   6541   3.278319
#  9th grade                                6230   3.122447
#  Associates degree-occup /vocational      5358   2.685405
#  Associates degree-academic program       4363   2.186715
#  5th or 6th grade                         3277   1.642417
#  12th grade no diploma                    2126   1.065541
#  1st 2nd 3rd or 4th grade                 1799   0.901650
#  Prof school degree (MD DDS DVM LLB JD)   1793   0.898643
#  Doctorate degree(PhD EdD)                1263   0.633010
#  Less than 1st grade                       819   0.410479
# ***************************************
# Describing Column wage_per_hour:
# count    199523.000000
# mean         55.426908
# std         274.896454
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        9999.000000
# Name: wage_per_hour, dtype: float64
# ***************************************
# Describing Column enrolled_in_edu_inst_last_wk:
#                          count          %
#  Not in universe        186943  93.694962
#  High school              6892   3.454238
#  College or university    5688   2.850799
# ***************************************
# Describing Column marital_status:
#                                   count          %
#  Never married                    86485  43.345880
#  Married-civilian spouse present  84222  42.211675
#  Divorced                         12710   6.370193
#  Widowed                          10463   5.244007
#  Separated                         3460   1.734136
#  Married-spouse absent             1518   0.760815
#  Married-A F spouse present         665   0.333295
# ***************************************
# Describing Column major_industry_code:
#                                        count          %
#  Not in universe or children          100684  50.462353
#  Retail trade                          17070   8.555405
#  Manufacturing-durable goods            9015   4.518276
#  Education                              8283   4.151401
#  Manufacturing-nondurable goods         6897   3.456744
#  Finance insurance and real estate      6145   3.079845
#  Construction                           5984   2.999153
#  Business and repair services           5651   2.832255
#  Medical except hospital                4683   2.347098
#  Public administration                  4610   2.310511
#  Other professional services            4482   2.246358
#  Transportation                         4209   2.109531
#  Hospital services                      3964   1.986738
#  Wholesale trade                        3596   1.802298
#  Agriculture                            3023   1.515114
#  Personal services except private HH    2937   1.472011
#  Social services                        2549   1.277547
#  Entertainment                          1651   0.827474
#  Communications                         1181   0.591912
#  Utilities and sanitary services        1178   0.590408
#  Private household services              945   0.473630
#  Mining                                  563   0.282173
#  Forestry and fisheries                  187   0.093724
#  Armed Forces                             36   0.018043
# ***************************************
# Describing Column major_occupation_code:
#                                          count          %
#  Not in universe                        100684  50.462353
#  Adm support including clerical          14837   7.436235
#  Professional specialty                  13940   6.986663
#  Executive admin and managerial          12495   6.262436
#  Other service                           12099   6.063963
#  Sales                                   11783   5.905585
#  Precision production craft & repair     10518   5.271573
#  Machine operators assmblrs & inspctrs    6379   3.197125
#  Handlers equip cleaners etc              4127   2.068433
#  Transportation and material moving       4020   2.014805
#  Farming forestry and fishing             3146   1.576761
#  Technicians and related support          3018   1.512608
#  Protective services                      1661   0.832485
#  Private household services                780   0.390932
#  Armed Forces                               36   0.018043
# ***************************************
# Describing Column race:
#                                count          %
#  White                        167365  83.882560
#  Black                         20415  10.231903
#  Asian or Pacific Islander      5835   2.924475
#  Other                          3657   1.832871
#  Amer Indian Aleut or Eskimo    2251   1.128191
# ***************************************
# Describing Column hispanic_Origin:
#                              count          %
#  All other                  171907  86.158989
#  Mexican-American             8079   4.049157
#  Mexican (Mexicano)           7234   3.625647
#  Central or South American    3895   1.952156
#  Puerto Rican                 3313   1.660460
#  Other Spanish                2485   1.245470
#  Cuban                        1126   0.564346
#  NA                            874   0.438045
#  Do not know                   306   0.153366
#  Chicano                       304   0.152363
# ***************************************
# Describing Column sex:
#           count          %
#  Female  103984  52.116297
#  Male     95539  47.883703
# ***************************************
# Describing Column member_of_a_labor_union:
#                    count          %
#  Not in universe  180459  90.445212
#  No                16034   8.036166
#  Yes                3030   1.518622
# ***************************************
# Describing Column reason_for_unemployment:
#                          count          %
#  Not in universe        193453  96.957744
#  Other job loser          2038   1.021436
#  Re-entrant               2019   1.011913
#  Job loser - on layoff     976   0.489167
#  Job leaver                598   0.299715
#  New entrant               439   0.220025
# ***************************************
# Describing Column full_or_part_time_employment_stat:
#                                       count          %
#  Children or Armed Forces            123769  62.032447
#  Full-time schedules                  40736  20.416694
#  Not in labor force                   26808  13.436045
#  PT for non-econ reasons usually FT    3322   1.664971
#  Unemployed full-time                  2311   1.158262
#  PT for econ reasons usually PT        1209   0.605945
#  Unemployed part- time                  843   0.422508
#  PT for econ reasons usually FT         525   0.263128
# ***************************************
# Describing Column capital_gains:
# count    199523.00000
# mean        434.71899
# std        4697.53128
# min           0.00000
# 25%           0.00000
# 50%           0.00000
# 75%           0.00000
# max       99999.00000
# Name: capital_gains, dtype: float64
# ***************************************
# Describing Column capital_losses:
# count    199523.000000
# mean         37.313788
# std         271.896428
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        4608.000000
# Name: capital_losses, dtype: float64
# ***************************************
# Describing Column divdends_from_stocks:
# count    199523.000000
# mean        197.529533
# std        1984.163658
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       99999.000000
# Name: divdends_from_stocks, dtype: float64
# ***************************************
# Describing Column tax_filer_status:
#                                count          %
#  Nonfiler                      75094  37.636764
#  Joint both under 65           67383  33.772046
#  Single                        37421  18.755231
#  Joint both 65+                 8332   4.175960
#  Head of household              7426   3.721877
#  Joint one under 65 & one 65+   3867   1.938122
# ***************************************
# Describing Column region_of_previous_residence:
#                    count          %
#  Not in universe  183750  92.094646
#  South              4889   2.450344
#  West               4074   2.041870
#  Midwest            3575   1.791773
#  Northeast          2705   1.355733
#  Abroad              530   0.265634
# ***************************************
# Describing Column state_of_previous_residence:
#                         count          %
#  Not in universe       183750  92.094646
#  California              1714   0.859049
#  Utah                    1063   0.532771
#  Florida                  849   0.425515
#  North Carolina           812   0.406971
#  ?                        708   0.354846
#  Abroad                   671   0.336302
#  Oklahoma                 626   0.313748
#  Minnesota                576   0.288689
#  Indiana                  533   0.267137
#  North Dakota             499   0.250096
#  New Mexico               463   0.232053
#  Michigan                 441   0.221027
#  Alaska                   290   0.145347
#  Kentucky                 244   0.122292
#  Arizona                  243   0.121790
#  New Hampshire            242   0.121289
#  Wyoming                  241   0.120788
#  Colorado                 239   0.119786
#  Oregon                   236   0.118282
#  West Virginia            231   0.115776
#  Georgia                  227   0.113771
#  Montana                  226   0.113270
#  Alabama                  216   0.108258
#  Ohio                     211   0.105752
#  Texas                    209   0.104750
#  Arkansas                 205   0.102745
#  Mississippi              204   0.102244
#  Tennessee                202   0.101241
#  Pennsylvania             199   0.099738
#  New York                 195   0.097733
#  Louisiana                192   0.096230
#  Vermont                  191   0.095728
#  Iowa                     189   0.094726
#  Illinois                 180   0.090215
#  Nebraska                 178   0.089213
#  Missouri                 175   0.087709
#  Nevada                   174   0.087208
#  Maine                    167   0.083700
#  Massachusetts            151   0.075680
#  Kansas                   149   0.074678
#  South Dakota             138   0.069165
#  Maryland                 136   0.068163
#  Virginia                 126   0.063151
#  Connecticut              117   0.058640
#  District of Columbia     116   0.058139
#  Wisconsin                105   0.052626
#  South Carolina            95   0.047614
#  New Jersey                75   0.037590
#  Delaware                  73   0.036587
#  Idaho                     31   0.015537
# ***************************************
# Describing Column detailed_household_and_family_stat:
#                                                   count          %
#  Householder                                      53248  26.687650
#  Child <18 never marr not in subfamily            50326  25.223157
#  Spouse of householder                            41695  20.897340
#  Nonfamily householder                            22213  11.133052
#  Child 18+ never marr Not in a subfamily          12030   6.029380
#  Secondary individual                              6122   3.068318
#  Other Rel 18+ ever marr not in subfamily          1956   0.980338
#  Grandchild <18 never marr child of subfamily RP   1868   0.936233
#  Other Rel 18+ never marr not in subfamily         1728   0.866066
#  Grandchild <18 never marr not in subfamily        1066   0.534274
#  Child 18+ ever marr Not in a subfamily            1013   0.507711
#  Child under 18 of RP of unrel subfamily            732   0.366875
#  RP of unrelated subfamily                          685   0.343319
#  Child 18+ ever marr RP of subfamily                671   0.336302
#  Other Rel <18 never marr child of subfamily RP     656   0.328784
#  Other Rel 18+ ever marr RP of subfamily            656   0.328784
#  Other Rel 18+ spouse of subfamily RP               638   0.319763
#  Child 18+ never marr RP of subfamily               589   0.295204
#  Other Rel <18 never marr not in subfamily          584   0.292698
#  Grandchild 18+ never marr not in subfamily         375   0.187948
#  In group quarters                                  196   0.098234
#  Child 18+ spouse of subfamily RP                   126   0.063151
#  Other Rel 18+ never marr RP of subfamily            94   0.047112
#  Child <18 never marr RP of subfamily                80   0.040096
#  Spouse of RP of unrelated subfamily                 52   0.026062
#  Child <18 ever marr not in subfamily                36   0.018043
#  Grandchild 18+ ever marr not in subfamily           34   0.017041
#  Grandchild 18+ spouse of subfamily RP               10   0.005012
#  Child <18 ever marr RP of subfamily                  9   0.004511
#  Grandchild 18+ ever marr RP of subfamily             9   0.004511
#  Other Rel <18 ever marr RP of subfamily              6   0.003007
#  Grandchild 18+ never marr RP of subfamily            6   0.003007
#  Other Rel <18 never married RP of subfamily          4   0.002005
#  Other Rel <18 spouse of subfamily RP                 3   0.001504
#  Grandchild <18 never marr RP of subfamily            2   0.001002
#  Child <18 spouse of subfamily RP                     2   0.001002
#  Grandchild <18 ever marr not in subfamily            2   0.001002
#  Other Rel <18 ever marr not in subfamily             1   0.000501
# ***************************************
# Describing Column detailed_household_summary_in_household:
#                                        count          %
#  Householder                           75475  37.827719
#  Child under 18 never married          50426  25.273277
#  Spouse of householder                 41709  20.904357
#  Child 18 or older                     14430   7.232249
#  Other relative of householder          9703   4.863098
#  Nonrelative of householder             7601   3.809586
#  Group Quarters- Secondary individual    132   0.066158
#  Child under 18 ever married              47   0.023556
# ***************************************
# Describing Column instance_weight:
# count    199523.000000
# mean       1740.380269
# std         993.768156
# min          37.870000
# 25%        1061.615000
# 50%        1618.310000
# 75%        2188.610000
# max       18656.300000
# Name: instance_weight, dtype: float64
# ***************************************
# Describing Column migration_code-change_in_msa:
#                    count          %
#  ?                 99696  49.967172
#  Nonmover          82538  41.367662
#  MSA to MSA        10601   5.313172
#  NonMSA to nonMSA   2811   1.408860
#  Not in universe    1516   0.759812
#  MSA to nonMSA       790   0.395944
#  NonMSA to MSA       615   0.308235
#  Abroad to MSA       453   0.227041
#  Not identifiable    430   0.215514
#  Abroad to nonMSA     73   0.036587
# ***************************************
# Describing Column migration_code-change_in_reg:
#                                  count          %
#  ?                               99696  49.967172
#  Nonmover                        82538  41.367662
#  Same county                      9812   4.917729
#  Different county same state      2797   1.401843
#  Not in universe                  1516   0.759812
#  Different region                 1178   0.590408
#  Different state same division     991   0.496685
#  Abroad                            530   0.265634
#  Different division same region    465   0.233056
# ***************************************
# Describing Column migration_code-move_within_reg:
#                                count          %
#  ?                             99696  49.967172
#  Nonmover                      82538  41.367662
#  Same county                    9812   4.917729
#  Different county same state    2797   1.401843
#  Not in universe                1516   0.759812
#  Different state in South        973   0.487663
#  Different state in West         679   0.340312
#  Different state in Midwest      551   0.276159
#  Abroad                          530   0.265634
#  Different state in Northeast    431   0.216015
# ***************************************
# Describing Column live_in_this_house_1_year_ago:
#                                     count          %
#  Not in universe under 1 year old  101212  50.726984
#  Yes                                82538  41.367662
#  No                                 15773   7.905354
# ***************************************
# Describing Column migration_prev_res_in_sunbelt:
#                   count          %
#  ?                99696  49.967172
#  Not in universe  84054  42.127474
#  No                9987   5.005438
#  Yes               5786   2.899916
# ***************************************
# Describing Column num_persons_worked_for_employer:
# count    199523.000000
# mean          1.956180
# std           2.365126
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           4.000000
# max           6.000000
# Name: num_persons_worked_for_employer, dtype: float64
# ***************************************
# Describing Column family_members_under_18:
#                           count          %
#  Not in universe         144232  72.288408
#  Both parents present     38983  19.538098
#  Mother only present      12772   6.401267
#  Father only present       1883   0.943751
#  Neither parent present    1653   0.828476
# ***************************************
# Describing Column country_of_birth_father:
#                                 count          %
#  United-States                 159163  79.771756
#  Mexico                         10008   5.015963
#  ?                               6713   3.364524
#  Puerto-Rico                     2680   1.343204
#  Italy                           2212   1.108644
#  Canada                          1380   0.691650
#  Germany                         1356   0.679621
#  Dominican-Republic              1290   0.646542
#  Poland                          1212   0.607449
#  Philippines                     1154   0.578379
#  Cuba                            1125   0.563845
#  El-Salvador                      982   0.492174
#  China                            856   0.429023
#  England                          793   0.397448
#  Columbia                         614   0.307734
#  India                            580   0.290693
#  South Korea                      530   0.265634
#  Ireland                          508   0.254607
#  Jamaica                          463   0.232053
#  Vietnam                          457   0.229046
#  Guatemala                        445   0.223032
#  Japan                            392   0.196469
#  Portugal                         388   0.194464
#  Ecuador                          379   0.189953
#  Haiti                            351   0.175920
#  Greece                           344   0.172411
#  Peru                             335   0.167900
#  Nicaragua                        315   0.157877
#  Hungary                          306   0.153366
#  Scotland                         247   0.123795
#  Iran                             233   0.116779
#  Yugoslavia                       217   0.108759
#  Taiwan                           199   0.099738
#  Cambodia                         196   0.098234
#  Honduras                         194   0.097232
#  France                           191   0.095728
#  Outlying-U S (Guam USVI etc)     159   0.079690
#  Laos                             154   0.077184
#  Trinadad&Tobago                  113   0.056635
#  Thailand                         107   0.053628
#  Hong Kong                        106   0.053127
#  Holand-Netherlands                51   0.025561
#  Panama                            25   0.012530
# ***************************************
# Describing Column country_of_birth_mother:
#                                 count          %
#  United-States                 160479  80.431329
#  Mexico                          9781   4.902192
#  ?                               6119   3.066814
#  Puerto-Rico                     2473   1.239456
#  Italy                           1844   0.924204
#  Canada                          1451   0.727234
#  Germany                         1382   0.692652
#  Philippines                     1231   0.616971
#  Poland                          1110   0.556327
#  Cuba                            1108   0.555324
#  El-Salvador                     1108   0.555324
#  Dominican-Republic              1103   0.552818
#  England                          903   0.452579
#  China                            760   0.380908
#  Columbia                         612   0.306732
#  South Korea                      609   0.305228
#  Ireland                          599   0.300216
#  India                            581   0.291194
#  Vietnam                          473   0.237065
#  Japan                            469   0.235061
#  Jamaica                          453   0.227041
#  Guatemala                        444   0.222531
#  Ecuador                          375   0.187948
#  Peru                             355   0.177924
#  Haiti                            353   0.176922
#  Portugal                         342   0.171409
#  Nicaragua                        301   0.150860
#  Hungary                          297   0.148855
#  Greece                           261   0.130812
#  Scotland                         241   0.120788
#  Taiwan                           222   0.111265
#  Honduras                         218   0.109261
#  France                           212   0.106253
#  Iran                             198   0.099237
#  Yugoslavia                       177   0.088712
#  Outlying-U S (Guam USVI etc)     157   0.078688
#  Cambodia                         157   0.078688
#  Laos                             155   0.077685
#  Thailand                         123   0.061647
#  Hong Kong                        107   0.053628
#  Trinadad&Tobago                   99   0.049618
#  Holand-Netherlands                49   0.024559
#  Panama                            32   0.016038
# ***************************************
# Describing Column country_of_birth_self:
#                                 count          %
#  United-States                 176989  88.706064
#  Mexico                          5767   2.890394
#  ?                               3393   1.700556
#  Puerto-Rico                     1400   0.701673
#  Germany                          851   0.426517
#  Philippines                      845   0.423510
#  Cuba                             837   0.419501
#  Canada                           700   0.350837
#  Dominican-Republic               690   0.345825
#  El-Salvador                      689   0.345324
#  China                            478   0.239571
#  South Korea                      471   0.236063
#  England                          457   0.229046
#  Columbia                         434   0.217519
#  Italy                            419   0.210001
#  India                            408   0.204488
#  Vietnam                          391   0.195967
#  Poland                           381   0.190955
#  Guatemala                        344   0.172411
#  Japan                            339   0.169905
#  Jamaica                          320   0.160383
#  Peru                             268   0.134320
#  Ecuador                          258   0.129308
#  Haiti                            228   0.114273
#  Nicaragua                        218   0.109261
#  Taiwan                           201   0.100740
#  Portugal                         174   0.087208
#  Iran                             157   0.078688
#  Greece                           147   0.073676
#  Honduras                         144   0.072172
#  Ireland                          135   0.067661
#  France                           121   0.060645
#  Outlying-U S (Guam USVI etc)     119   0.059642
#  Thailand                         113   0.056635
#  Laos                             105   0.052626
#  Hong Kong                        100   0.050120
#  Cambodia                          95   0.047614
#  Hungary                           79   0.039594
#  Scotland                          75   0.037590
#  Yugoslavia                        66   0.033079
#  Trinadad&Tobago                   66   0.033079
#  Panama                            28   0.014033
#  Holand-Netherlands                23   0.011527
# ***************************************
# Describing Column citizenship:
#                                                count          %
#  Native- Born in the United States            176992  88.707568
#  Foreign born- Not a citizen of U S            13401   6.716519
#  Foreign born- U S citizen by naturalization    5855   2.934499
#  Native- Born abroad of American Parent(s)      1756   0.880099
#  Native- Born in Puerto Rico or U S Outlying    1519   0.761316
# ***************************************
# Describing Column own_business_or_self_employed:
#     count          %
# 0  180672  90.551966
# 2   16153   8.095809
# 1    2698   1.352225
# ***************************************
# Describing Column fill_inc_questionnaire_for_veteran's_admin:
#                    count          %
#  Not in universe  197539  99.005628
#  No                 1593   0.798404
#  Yes                 391   0.195967
# ***************************************
# Describing Column veterans_benefits:
#     count          %
# 2  150130  75.244458
# 0   47409  23.761170
# 1    1984   0.994372
# ***************************************
# Describing Column weeks_worked_in_year:
# count    199523.000000
# mean         23.174897
# std          24.411488
# min           0.000000
# 25%           0.000000
# 50%           8.000000
# 75%          52.000000
# max          52.000000
# Name: weeks_worked_in_year, dtype: float64
# ***************************************
# Describing Column year:
#     count          %
# 94  99827  50.032828
# 95  99696  49.967172
# ***************************************
# Describing Column total_person_income:
#             count          %
#  - 50000.  187141  93.794199
#  50000+.    12382   6.205801

# %% [markdown]
# #### Audit the test data too

# %%
test = pd.read_csv('us_census_full/census_income_test.csv', header=None, names=columnNames)

# %% [markdown]
# Let's check the <a href="http://ucanalytics.com/blogs/population-stability-index-psi-banking-case-study/">Population Stability Index</a> (PSI) to see if the test data is in a similar context than the training data or if we need to ignore some features because they happened to be too different in the test dataset.

# %%
epsilon = 0.005

def computePSI(actual, expected):
    a = epsilon
    act = actual.value_counts()
    totalAct = 1.0 * act.values.sum()
    exp = expected.value_counts();
    totalExp = 1.0 * exp.values.sum()
    for actKey in act.keys():
        if actKey not in exp.keys():
            exp = exp.append(pd.Series([a], index=[actKey]))
    for expKey in exp.keys():
        if expKey not in act.keys():
            act = act.append(pd.Series([a], index=[expKey]))
    act = act.values / totalAct
    exp = exp.values / totalExp
    try:
        PSI = (act - exp) * np.log(act / exp)
    except:
        print act, exp
    return PSI.sum()

for var_name in columnNames:
    if train[var_name].dtype != np.float64:
        PSI = computePSI(train[var_name], test[var_name])
        if PSI > epsilon:
            print var_name + " has a PSI of " + str(PSI)
# Out:
# wage_per_hour has a PSI of 0.00896227576458
# divdends_from_stocks has a PSI of 0.00884941156761

# %% [markdown]
# All the PSI measures for each features seems to be quite low so we don't need to worry about it in this exercise but this could be used as a test on production data to detect any shift in the day-to-day data that are fed to the model once it is deployed.
#
# This kind of verification would ensure that we would get alerted if there is a sudden change in the behavior of the population (which is not the context expected for this model to work properly)

# %% [markdown]
# #### Visualize without missing values

# %%
missingValues = [
    " Not in universe",
    " ?"
]
def describeWithoutNull(df):
    for i in df.columns:
        numValues = pd.Series(df[i].values.ravel()).unique().size
        if df[i].dtype ==  np.object or numValues <= 5:
            print "***************************************"
            print "Describing Column " + str(i) + ":" 
            auditCategoricalColumn(df[~df[i].isin(missingValues)], str(i))

# %%
describeWithoutNull(train)
# Out:
# ***************************************
# Describing Column class_of_worker:
#                                  count          %
#  Private                         72028  72.551824
#  Self-employed-not incorporated   8445   8.506416
#  Local government                 7784   7.840609
#  State government                 4227   4.257741
#  Self-employed-incorporated       3265   3.288745
#  Federal government               2925   2.946272
#  Never worked                      439   0.442193
#  Without pay                       165   0.166200
# ***************************************
# Describing Column education:
#                                          count          %
#  High school graduate                    48407  24.261363
#  Children                                47422  23.767686
#  Some college but no degree              27820  13.943255
#  Bachelors degree(BA AB BS)              19865   9.956246
#  7th and 8th grade                        8007   4.013071
#  10th grade                               7557   3.787533
#  11th grade                               6876   3.446219
#  Masters degree(MA MS MEng MEd MSW MBA)   6541   3.278319
#  9th grade                                6230   3.122447
#  Associates degree-occup /vocational      5358   2.685405
#  Associates degree-academic program       4363   2.186715
#  5th or 6th grade                         3277   1.642417
#  12th grade no diploma                    2126   1.065541
#  1st 2nd 3rd or 4th grade                 1799   0.901650
#  Prof school degree (MD DDS DVM LLB JD)   1793   0.898643
#  Doctorate degree(PhD EdD)                1263   0.633010
#  Less than 1st grade                       819   0.410479
# ***************************************
# Describing Column enrolled_in_edu_inst_last_wk:
#                         count          %
#  High school             6892  54.785374
#  College or university   5688  45.214626
# ***************************************
# Describing Column marital_status:
#                                   count          %
#  Never married                    86485  43.345880
#  Married-civilian spouse present  84222  42.211675
#  Divorced                         12710   6.370193
#  Widowed                          10463   5.244007
#  Separated                         3460   1.734136
#  Married-spouse absent             1518   0.760815
#  Married-A F spouse present         665   0.333295
# ***************************************
# Describing Column major_industry_code:
#                                        count          %
#  Not in universe or children          100684  50.462353
#  Retail trade                          17070   8.555405
#  Manufacturing-durable goods            9015   4.518276
#  Education                              8283   4.151401
#  Manufacturing-nondurable goods         6897   3.456744
#  Finance insurance and real estate      6145   3.079845
#  Construction                           5984   2.999153
#  Business and repair services           5651   2.832255
#  Medical except hospital                4683   2.347098
#  Public administration                  4610   2.310511
#  Other professional services            4482   2.246358
#  Transportation                         4209   2.109531
#  Hospital services                      3964   1.986738
#  Wholesale trade                        3596   1.802298
#  Agriculture                            3023   1.515114
#  Personal services except private HH    2937   1.472011
#  Social services                        2549   1.277547
#  Entertainment                          1651   0.827474
#  Communications                         1181   0.591912
#  Utilities and sanitary services        1178   0.590408
#  Private household services              945   0.473630
#  Mining                                  563   0.282173
#  Forestry and fisheries                  187   0.093724
#  Armed Forces                             36   0.018043
# ***************************************
# Describing Column major_occupation_code:
#                                         count          %
#  Adm support including clerical         14837  15.011281
#  Professional specialty                 13940  14.103744
#  Executive admin and managerial         12495  12.641771
#  Other service                          12099  12.241119
#  Sales                                  11783  11.921408
#  Precision production craft & repair    10518  10.641548
#  Machine operators assmblrs & inspctrs   6379   6.453930
#  Handlers equip cleaners etc             4127   4.175477
#  Transportation and material moving      4020   4.067220
#  Farming forestry and fishing            3146   3.182954
#  Technicians and related support         3018   3.053451
#  Protective services                     1661   1.680511
#  Private household services               780   0.789162
#  Armed Forces                              36   0.036423
# ***************************************
# Describing Column race:
#                                count          %
#  White                        167365  83.882560
#  Black                         20415  10.231903
#  Asian or Pacific Islander      5835   2.924475
#  Other                          3657   1.832871
#  Amer Indian Aleut or Eskimo    2251   1.128191
# ***************************************
# Describing Column hispanic_Origin:
#                              count          %
#  All other                  171907  86.158989
#  Mexican-American             8079   4.049157
#  Mexican (Mexicano)           7234   3.625647
#  Central or South American    3895   1.952156
#  Puerto Rican                 3313   1.660460
#  Other Spanish                2485   1.245470
#  Cuban                        1126   0.564346
#  NA                            874   0.438045
#  Do not know                   306   0.153366
#  Chicano                       304   0.152363
# ***************************************
# Describing Column sex:
#           count          %
#  Female  103984  52.116297
#  Male     95539  47.883703
# ***************************************
# Describing Column member_of_a_labor_union:
#       count          %
#  No   16034  84.106169
#  Yes   3030  15.893831
# ***************************************
# Describing Column reason_for_unemployment:
#                         count          %
#  Other job loser         2038  33.574959
#  Re-entrant              2019  33.261944
#  Job loser - on layoff    976  16.079077
#  Job leaver               598   9.851730
#  New entrant              439   7.232290
# ***************************************
# Describing Column full_or_part_time_employment_stat:
#                                       count          %
#  Children or Armed Forces            123769  62.032447
#  Full-time schedules                  40736  20.416694
#  Not in labor force                   26808  13.436045
#  PT for non-econ reasons usually FT    3322   1.664971
#  Unemployed full-time                  2311   1.158262
#  PT for econ reasons usually PT        1209   0.605945
#  Unemployed part- time                  843   0.422508
#  PT for econ reasons usually FT         525   0.263128
# ***************************************
# Describing Column tax_filer_status:
#                                count          %
#  Nonfiler                      75094  37.636764
#  Joint both under 65           67383  33.772046
#  Single                        37421  18.755231
#  Joint both 65+                 8332   4.175960
#  Head of household              7426   3.721877
#  Joint one under 65 & one 65+   3867   1.938122
# ***************************************
# Describing Column region_of_previous_residence:
#             count          %
#  South       4889  30.996006
#  West        4074  25.828948
#  Midwest     3575  22.665314
#  Northeast   2705  17.149559
#  Abroad       530   3.360172
# ***************************************
# Describing Column state_of_previous_residence:
#                        count          %
#  California             1714  11.377365
#  Utah                   1063   7.056090
#  Florida                 849   5.635579
#  North Carolina          812   5.389977
#  Abroad                  671   4.454033
#  Oklahoma                626   4.155327
#  Minnesota               576   3.823432
#  Indiana                 533   3.538002
#  North Dakota            499   3.312313
#  New Mexico              463   3.073349
#  Michigan                441   2.927315
#  Alaska                  290   1.924992
#  Kentucky                244   1.619648
#  Arizona                 243   1.613010
#  New Hampshire           242   1.606372
#  Wyoming                 241   1.599734
#  Colorado                239   1.586459
#  Oregon                  236   1.566545
#  West Virginia           231   1.533355
#  Georgia                 227   1.506804
#  Montana                 226   1.500166
#  Alabama                 216   1.433787
#  Ohio                    211   1.400597
#  Texas                   209   1.387322
#  Arkansas                205   1.360770
#  Mississippi             204   1.354132
#  Tennessee               202   1.340856
#  Pennsylvania            199   1.320943
#  New York                195   1.294391
#  Louisiana               192   1.274477
#  Vermont                 191   1.267839
#  Iowa                    189   1.254564
#  Illinois                180   1.194822
#  Nebraska                178   1.181547
#  Missouri                175   1.161633
#  Nevada                  174   1.154995
#  Maine                   167   1.108530
#  Massachusetts           151   1.002323
#  Kansas                  149   0.989047
#  South Dakota            138   0.916031
#  Maryland                136   0.902755
#  Virginia                126   0.836376
#  Connecticut             117   0.776635
#  District of Columbia    116   0.769997
#  Wisconsin               105   0.696980
#  South Carolina           95   0.630601
#  New Jersey               75   0.497843
#  Delaware                 73   0.484567
#  Idaho                    31   0.205775
# ***************************************
# Describing Column detailed_household_and_family_stat:
#                                                   count          %
#  Householder                                      53248  26.687650
#  Child <18 never marr not in subfamily            50326  25.223157
#  Spouse of householder                            41695  20.897340
#  Nonfamily householder                            22213  11.133052
#  Child 18+ never marr Not in a subfamily          12030   6.029380
#  Secondary individual                              6122   3.068318
#  Other Rel 18+ ever marr not in subfamily          1956   0.980338
#  Grandchild <18 never marr child of subfamily RP   1868   0.936233
#  Other Rel 18+ never marr not in subfamily         1728   0.866066
#  Grandchild <18 never marr not in subfamily        1066   0.534274
#  Child 18+ ever marr Not in a subfamily            1013   0.507711
#  Child under 18 of RP of unrel subfamily            732   0.366875
#  RP of unrelated subfamily                          685   0.343319
#  Child 18+ ever marr RP of subfamily                671   0.336302
#  Other Rel <18 never marr child of subfamily RP     656   0.328784
#  Other Rel 18+ ever marr RP of subfamily            656   0.328784
#  Other Rel 18+ spouse of subfamily RP               638   0.319763
#  Child 18+ never marr RP of subfamily               589   0.295204
#  Other Rel <18 never marr not in subfamily          584   0.292698
#  Grandchild 18+ never marr not in subfamily         375   0.187948
#  In group quarters                                  196   0.098234
#  Child 18+ spouse of subfamily RP                   126   0.063151
#  Other Rel 18+ never marr RP of subfamily            94   0.047112
#  Child <18 never marr RP of subfamily                80   0.040096
#  Spouse of RP of unrelated subfamily                 52   0.026062
#  Child <18 ever marr not in subfamily                36   0.018043
#  Grandchild 18+ ever marr not in subfamily           34   0.017041
#  Grandchild 18+ spouse of subfamily RP               10   0.005012
#  Child <18 ever marr RP of subfamily                  9   0.004511
#  Grandchild 18+ ever marr RP of subfamily             9   0.004511
#  Other Rel <18 ever marr RP of subfamily              6   0.003007
#  Grandchild 18+ never marr RP of subfamily            6   0.003007
#  Other Rel <18 never married RP of subfamily          4   0.002005
#  Other Rel <18 spouse of subfamily RP                 3   0.001504
#  Grandchild <18 never marr RP of subfamily            2   0.001002
#  Child <18 spouse of subfamily RP                     2   0.001002
#  Grandchild <18 ever marr not in subfamily            2   0.001002
#  Other Rel <18 ever marr not in subfamily             1   0.000501
# ***************************************
# Describing Column detailed_household_summary_in_household:
#                                        count          %
#  Householder                           75475  37.827719
#  Child under 18 never married          50426  25.273277
#  Spouse of householder                 41709  20.904357
#  Child 18 or older                     14430   7.232249
#  Other relative of householder          9703   4.863098
#  Nonrelative of householder             7601   3.809586
#  Group Quarters- Secondary individual    132   0.066158
#  Child under 18 ever married              47   0.023556
# ***************************************
# Describing Column migration_code-change_in_msa:
#                    count          %
#  Nonmover          82538  83.956017
#  MSA to MSA        10601  10.783127
#  NonMSA to nonMSA   2811   2.859293
#  MSA to nonMSA       790   0.803572
#  NonMSA to MSA       615   0.625566
#  Abroad to MSA       453   0.460783
#  Not identifiable    430   0.437387
#  Abroad to nonMSA     73   0.074254
# ***************************************
# Describing Column migration_code-change_in_reg:
#                                  count          %
#  Nonmover                        82538  83.956017
#  Same county                      9812   9.980572
#  Different county same state      2797   2.845053
#  Different region                 1178   1.198238
#  Different state same division     991   1.008026
#  Abroad                            530   0.539105
#  Different division same region    465   0.472989
# ***************************************
# Describing Column migration_code-move_within_reg:
#                                count          %
#  Nonmover                      82538  83.956017
#  Same county                    9812   9.980572
#  Different county same state    2797   2.845053
#  Different state in South        973   0.989716
#  Different state in West         679   0.690665
#  Different state in Midwest      551   0.560466
#  Abroad                          530   0.539105
#  Different state in Northeast    431   0.438405
# ***************************************
# Describing Column live_in_this_house_1_year_ago:
#                                     count          %
#  Not in universe under 1 year old  101212  50.726984
#  Yes                                82538  41.367662
#  No                                 15773   7.905354
# ***************************************
# Describing Column migration_prev_res_in_sunbelt:
#       count          %
#  No    9987  63.317061
#  Yes   5786  36.682939
# ***************************************
# Describing Column family_members_under_18:
#                          count          %
#  Both parents present    38983  70.505146
#  Mother only present     12772  23.099600
#  Father only present      1883   3.405618
#  Neither parent present   1653   2.989637
# ***************************************
# Describing Column country_of_birth_father:
#                                 count          %
#  United-States                 159163  82.549142
#  Mexico                         10008   5.190602
#  Puerto-Rico                     2680   1.389969
#  Italy                           2212   1.147243
#  Canada                          1380   0.715731
#  Germany                         1356   0.703283
#  Dominican-Republic              1290   0.669052
#  Poland                          1212   0.628598
#  Philippines                     1154   0.598517
#  Cuba                            1125   0.583476
#  El-Salvador                      982   0.509310
#  China                            856   0.443960
#  England                          793   0.411286
#  Columbia                         614   0.318448
#  India                            580   0.300814
#  South Korea                      530   0.274882
#  Ireland                          508   0.263472
#  Jamaica                          463   0.240133
#  Vietnam                          457   0.237021
#  Guatemala                        445   0.230797
#  Japan                            392   0.203309
#  Portugal                         388   0.201234
#  Ecuador                          379   0.196567
#  Haiti                            351   0.182044
#  Greece                           344   0.178414
#  Peru                             335   0.173746
#  Nicaragua                        315   0.163373
#  Hungary                          306   0.158705
#  Scotland                         247   0.128105
#  Iran                             233   0.120844
#  Yugoslavia                       217   0.112546
#  Taiwan                           199   0.103210
#  Cambodia                         196   0.101654
#  Honduras                         194   0.100617
#  France                           191   0.099061
#  Outlying-U S (Guam USVI etc)     159   0.082465
#  Laos                             154   0.079871
#  Trinadad&Tobago                  113   0.058607
#  Thailand                         107   0.055495
#  Hong Kong                        106   0.054976
#  Holand-Netherlands                51   0.026451
#  Panama                            25   0.012966
# ***************************************
# Describing Column country_of_birth_mother:
#                                 count          %
#  United-States                 160479  82.976050
#  Mexico                          9781   5.057289
#  Puerto-Rico                     2473   1.278671
#  Italy                           1844   0.953445
#  Canada                          1451   0.750243
#  Germany                         1382   0.714566
#  Philippines                     1231   0.636491
#  Poland                          1110   0.573928
#  Cuba                            1108   0.572894
#  El-Salvador                     1108   0.572894
#  Dominican-Republic              1103   0.570309
#  England                          903   0.466898
#  China                            760   0.392960
#  Columbia                         612   0.316436
#  South Korea                      609   0.314885
#  Ireland                          599   0.309714
#  India                            581   0.300407
#  Vietnam                          473   0.244566
#  Japan                            469   0.242498
#  Jamaica                          453   0.234225
#  Guatemala                        444   0.229571
#  Ecuador                          375   0.193895
#  Peru                             355   0.183554
#  Haiti                            353   0.182519
#  Portugal                         342   0.176832
#  Nicaragua                        301   0.155633
#  Hungary                          297   0.153565
#  Greece                           261   0.134951
#  Scotland                         241   0.124610
#  Taiwan                           222   0.114786
#  Honduras                         218   0.112717
#  France                           212   0.109615
#  Iran                             198   0.102376
#  Yugoslavia                       177   0.091518
#  Outlying-U S (Guam USVI etc)     157   0.081177
#  Cambodia                         157   0.081177
#  Laos                             155   0.080143
#  Thailand                         123   0.063597
#  Hong Kong                        107   0.055325
#  Trinadad&Tobago                   99   0.051188
#  Holand-Netherlands                49   0.025336
#  Panama                            32   0.016546
# ***************************************
# Describing Column country_of_birth_self:
#                                 count          %
#  United-States                 176989  90.240657
#  Mexico                          5767   2.940397
#  Puerto-Rico                     1400   0.713812
#  Germany                          851   0.433896
#  Philippines                      845   0.430837
#  Cuba                             837   0.426758
#  Canada                           700   0.356906
#  Dominican-Republic               690   0.351807
#  El-Salvador                      689   0.351298
#  China                            478   0.243716
#  South Korea                      471   0.240147
#  England                          457   0.233009
#  Columbia                         434   0.221282
#  Italy                            419   0.213634
#  India                            408   0.208025
#  Vietnam                          391   0.199358
#  Poland                           381   0.194259
#  Guatemala                        344   0.175394
#  Japan                            339   0.172845
#  Jamaica                          320   0.163157
#  Peru                             268   0.136644
#  Ecuador                          258   0.131545
#  Haiti                            228   0.116249
#  Nicaragua                        218   0.111151
#  Taiwan                           201   0.102483
#  Portugal                         174   0.088717
#  Iran                             157   0.080049
#  Greece                           147   0.074950
#  Honduras                         144   0.073421
#  Ireland                          135   0.068832
#  France                           121   0.061694
#  Outlying-U S (Guam USVI etc)     119   0.060674
#  Thailand                         113   0.057615
#  Laos                             105   0.053536
#  Hong Kong                        100   0.050987
#  Cambodia                          95   0.048437
#  Hungary                           79   0.040279
#  Scotland                          75   0.038240
#  Yugoslavia                        66   0.033651
#  Trinadad&Tobago                   66   0.033651
#  Panama                            28   0.014276
#  Holand-Netherlands                23   0.011727
# ***************************************
# Describing Column citizenship:
#                                                count          %
#  Native- Born in the United States            176992  88.707568
#  Foreign born- Not a citizen of U S            13401   6.716519
#  Foreign born- U S citizen by naturalization    5855   2.934499
#  Native- Born abroad of American Parent(s)      1756   0.880099
#  Native- Born in Puerto Rico or U S Outlying    1519   0.761316
# ***************************************
# Describing Column own_business_or_self_employed:
#     count          %
# 0  180672  90.551966
# 2   16153   8.095809
# 1    2698   1.352225
# ***************************************
# Describing Column fill_inc_questionnaire_for_veteran's_admin:
#       count          %
#  No    1593  80.292339
#  Yes    391  19.707661
# ***************************************
# Describing Column veterans_benefits:
#     count          %
# 2  150130  75.244458
# 0   47409  23.761170
# 1    1984   0.994372
# ***************************************
# Describing Column year:
#     count          %
# 94  99827  50.032828
# 95  99696  49.967172
# ***************************************
# Describing Column total_person_income:
#             count          %
#  - 50000.  187141  93.794199
#  50000+.    12382   6.205801

# %% [markdown]
# #### Study missing values

# %% [markdown]
# Rows with missing values shouldn't be ignored completely but a deeper analysis of why it is happening and looking for any obvious pattern could be critical to better understand the data (or the way the data was acquired).

# %%
# FIXME

# %% [markdown]
# # Data Preparation

# %% [markdown]
# #### Convert to Spark DataFrame

# %%
trainDF = sqlContext.createDataFrame(train)
testDF = sqlContext.createDataFrame(test)

# %% [markdown]
# #### Encode categorical features

# %%
# assemble multiple columns into a single vector column
def prepareData(df):
    vectorAssembler = VectorAssembler(inputCols = [ w.replace(' ', '_') for w in [
        "age",
        "class of worker",
        "industry code",
        "occupation code",
        #"adjusted gross income",
        "education",
        "wage per hour",
        "enrolled in edu inst last wk",
        "marital status",
        "major industry code",
        "major occupation code",
        "race",
        "hispanic Origin",
        "sex",
        "member of a labor union",
        "reason for unemployment",
        "full or part time employment stat",
        "capital gains",
        "capital losses",
        "divdends from stocks",
        #"federal income tax liability",
        "tax filer status",
        "region of previous residence",
        "state of previous residence",
        "detailed household and family stat",
        "detailed household summary in household",
        #"instance weight",
        "migration code-change in msa",
        "migration code-change in reg",
        "migration code-move within reg",
        "live in this house 1 year ago",
        "migration prev res in sunbelt",
        "num persons worked for employer",
        "family members under 18",
        #"total person earnings",
        "country of birth father",
        "country of birth mother",
        "country of birth self",
        "citizenship",
        "own business or self employed",
        "fill inc questionnaire for veteran's admin",
        "veterans benefits",
        "weeks worked in year",
        #"taxable income amount",
        "year"
    ]], outputCol = "features")
    return vectorAssembler.transform(df)
    
# for each string feature, build a string indexer model
def modelEncoders(df):
    models = {}
    selectedFeatures = []
    for i in df.columns:
        if df.select(i).dtypes[0][1] == 'string':
            stringIndexer = StringIndexer(inputCol = i, 
                                          outputCol = "str_" + i)
            models[i] = stringIndexer.fit(df)
    return models

# for each string feature, transform it into double index using the string models
def encodeStringFeatures(df, models):
    selectedFeatures = []
    for i in df.columns:
        if df.select(i).dtypes[0][1] == 'string':
            model = models[i]
            indexed = model.transform(df)
            if i == targetColumn:
                df = indexed.drop(i).withColumnRenamed("str_" + i, i)
            else:
                encoder = OneHotEncoder(dropLast=False, inputCol="str_" + i, outputCol=i)
                encoded = encoder.transform(indexed.drop(i))
                df = encoded
            selectedFeatures.append(i)
        else:
            selectedFeatures.append(i)
    return df.select(selectedFeatures)

stringModels = modelEncoders(trainDF)
trainData = prepareData(encodeStringFeatures(trainDF, stringModels))
testData = prepareData(encodeStringFeatures(testDF, stringModels))
print trainData.select(targetColumn, "features").head()
# Out:
# Row(total_person_income=0.0, features=SparseVector(408, {0: 73.0, 1: 1.0, 12: 1.0, 30: 1.0, 36: 1.0, 40: 1.0, 64: 1.0, 79: 1.0, 84: 1.0, 94: 1.0, 96: 1.0, 99: 1.0, 107: 1.0, 116: 1.0, 122: 1.0, 128: 1.0, 185: 1.0, 221: 1.0, 225: 1.0, 235: 1.0, 244: 1.0, 254: 1.0, 257: 1.0, 262: 1.0, 267: 1.0, 310: 1.0, 353: 1.0, 396: 1.0, 402: 1.0, 405: 2.0, 407: 95.0}))

# %% [markdown]
# I am using <a href="https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.feature.OneHotEncoder">OneHotEncoder</a> which creates a new boolean column for each category value but I should investigate in the future the use of VectorIndexer instead as it seems to be more adequate to our use case and might improve performances: <a href="https://spark.apache.org/docs/latest/ml-features.html#vectorindexer">see documentation here</a> for handling categorical features
#
# However, since it would be a <a href="https://en.wikipedia.org/wiki/Lean_software_development#Eliminate_waste">waste</a> (in terms of lean development) to work on this aspect for now, I am leaving it out (ie result could still be achieved without it)

# %% [markdown]
# # Modeling

# %% [markdown]
# * Create a model using these variables (you can use whichever variables you want, or even create you own; for example, you could find the ratio or relationship between different variables, the binarisation of “categorical” variables, etc.) to modelize earning more or less than $50,000 / year. Here, the idea would be for you to test one or two algorithms, type regression logistics, or a decision tree. But, you are free to choose others if you’d rather.

# %% [markdown]
# #### Random Forest model

# %%
def trainRandomForest(df):
    rf = RandomForestClassifier(labelCol=targetColumn, 
                                featuresCol="features", 
                                rawPredictionCol="rawPrediction",
                                probabilityCol="probability",
                                numTrees=50)
    model = rf.fit(df)
    return model

# %% [markdown]
# * Choose the model that appears to have the highest performance based on a comparison between reality (the 42nd variable) and the model’s prediction.

# %% [markdown]
# From <a href="https://spark.apache.org/docs/latest/mllib-evaluation-metrics.html">MLLib documentation</a>:
# ## Classification model evaluation
# While there are many different types of classification algorithms, the evaluation of classification models all share similar principles. In a supervised classification problem, there exists a true output and a model-generated predicted output for each data point. For this reason, the results for each data point can be assigned to one of four categories:
#
# * True Positive (TP) - label is positive and prediction is also positive
# * True Negative (TN) - label is negative and prediction is also negative
# * False Positive (FP) - label is negative but prediction is positive
# * False Negative (FN) - label is positive but prediction is negative
#
# These four numbers are the building blocks for most classifier evaluation metrics. A fundamental point when considering classifier evaluation is that pure accuracy (i.e. was the prediction correct or incorrect) is not generally a good metric. The reason for this is because a dataset may be highly unbalanced. For example, if a model is designed to predict fraud from a dataset where 95% of the data points are not fraud and 5% of the data points are fraud, then a naive classifier that predicts not fraud, regardless of input, will be 95% accurate. For this reason, metrics like precision and recall are typically used because they take into account the type of error. In most applications there is some desired balance between precision and recall, which can be captured by combining the two into a single metric, called the F-measure.
#
# Here is a list of some possible measurements (from Dataiku's DSS):
# * Accuracy Score: Proportion of correct predictions (positive and negative) in the sample
# * Average Precision Score: Average precision for all classes
# * F1 Score: Harmonic mean of Precision and Recall
# * Hamming Loss: The Hamming loss is the fraction of labels that are incorrectly predicted. (The lower the better)
# * Log Loss: Error metric that takes into account the predicted probabilities
# * Matthews Correlation Coefficient: The MCC is a correlation coefficient between actual and predicted classifications; +1 is perfect, -1 means no correlation
# * Precision Score: Proportion of correct 'positive' predictions in the sample
# * ROC - AUC Score: From 0.5 (random model) to 1 (perfect model).
# * Recall Score

# %%
def measurePerformance(data, model = None):
    print
    print "Perfect Model"
    data.crosstab(targetColumn, targetColumn).show()

    print "Random Forest"
    if model == None:
        model = trainRandomForest(data)
    predictions = model.transform(data)
    confusionMat = predictions.crosstab(targetColumn, "prediction")
    if "1.0" in confusionMat.columns:
        confusionMat.show()
    else:
        confusionMat.withColumn("1.0", lit(0)).show()
        
    evaluator = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", labelCol=targetColumn)
    print "Area Under ROC Curve: " + str(evaluator.evaluate(predictions))
    print "Area Under Precision-Recall Curve: " + str(evaluator.evaluate(predictions, {evaluator.metricName: "areaUnderPR"}))
        
    print "Precision:", evaluatePrecision(confusionMat)
    return model

def evaluatePrecision(confusionMat):
    tp, fp, tn, fn = getConfusionMatrixCells(confusionMat)
    if (tp + fp) != 0:
        return tp * 1.0 / (tp + fp)
    else:
        return 0.0
        
def getConfusionMatrixCells(confusionMat):
    if "1.0" in confusionMat.columns:
        #True Positive (TP) - label is positive and prediction is also positive
        tp = confusionMat.where(confusionMat[targetColumn + "_prediction"] == "1.0").collect()[0]['1.0']
        #False Positive (FP) - label is negative but prediction is positive
        fp = confusionMat.where(confusionMat[targetColumn + "_prediction"] == "0.0").collect()[0]['1.0'] 
    else:
        tp = 0.0
        fp = 0.0
    if "0.0" in confusionMat.columns:
        #True Negative (TN) - label is negative and prediction is also negative
        tn = confusionMat.where(confusionMat[targetColumn + "_prediction"] == "0.0").collect()[0]['0.0']  
        #False Negative (FN) - label is positive but prediction is negative
        fn = confusionMat.where(confusionMat[targetColumn + "_prediction"] == "1.0").collect()[0]['0.0'] 
    else:
        tn = 0.0
        fn = 0.0
    return tp, fp, tn, fn

# %%
print "Always returning 0"
trainData.withColumn("always0", lit(0)).crosstab(targetColumn, "always0").withColumn("1.0", lit(0)).show()

#print "Always returning 1"
#trainData.withColumn("always1", lit(1)).crosstab(targetColumn, "always1").withColumn("0.0", lit(0)).show()

firstModel = measurePerformance(trainData)
# Out:
# Always returning 0
# +---------------------------+------+---+
# |total_person_income_always0|     0|1.0|
# +---------------------------+------+---+
# |                        1.0| 12382|  0|
# |                        0.0|187141|  0|
# +---------------------------+------+---+
# Perfect Model
# +---------------------------------------+-----+------+
# |total_person_income_total_person_income|  1.0|   0.0|
# +---------------------------------------+-----+------+
# |                                    1.0|12382|     0|
# |                                    0.0|    0|187141|
# +---------------------------------------+-----+------+
# Random Forest
# +------------------------------+------+---+
# |total_person_income_prediction|   0.0|1.0|
# +------------------------------+------+---+
# |                           1.0| 12382|  0|
# |                           0.0|187141|  0|
# +------------------------------+------+---+
# Area Under ROC Curve: 0.925782096884
# Area Under Precision-Recall Curve: 0.526448597715
# Precision:
# 0.0

# %% [markdown]
# Obviously, we see that something terribly wrong is happening as our very complicated piece of machine learning, Random Forest, is making exactly the same predictions as returning the same label (0.0) all the time. This is caused by the very unbalanced dataset as we have seen on previous charts...
#
# However, I wanted to make sure that i would be able to produce some models as fast as possible, regardless of the accuracy results at first. Now there is a full pipeline in place, we should be able to start the creative work and iterate as fast as possible while trying different methods and compare results with previous runs and slowly improve our predictions in a more efficient manner.
#
# So, let's now follow the "standard" Data Mining process (CRISP-DM) and go back to improve our predictions:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/b9/CRISP-DM_Process_Diagram.png", width=512>

# %% [markdown]
# # Data Preparation

# %% [markdown]
# #### Stratified Sampling: Down sample

# %% [markdown]
# Since the dataset is very unbalanced, the easiest (and fastest solution to implement) to this issue is to throw away data by "down sampling" the rows with the majority class (warning: this might not be the best solution!)

# %%
def downSample(df, factor = 1.0):
    targetCount = (df
       .groupBy(targetColumn).count()
       .sort("count", ascending= True)
       .map(lambda x: (x[targetColumn], x["count"]))
       .collect())
    fractions = { 
        targetCount[0][0] : 1.0,
        targetCount[1][0] : (targetCount[0][1] * 1.0 / targetCount[1][1]) * factor
    }
    return df.sampleBy(targetColumn, fractions)

sampleTrainData = downSample(trainData)
sampleTrainData.groupBy(targetColumn).count().show()
# Out:
# +-------------------+-----+
# |total_person_income|count|
# +-------------------+-----+
# |                1.0|12382|
# |                0.0|12436|
# +-------------------+-----+

# %% [markdown]
# # Modeling

# %%
secondModel = measurePerformance(sampleTrainData)
# Out:
# Perfect Model
# +---------------------------------------+-----+-----+
# |total_person_income_total_person_income|  1.0|  0.0|
# +---------------------------------------+-----+-----+
# |                                    1.0|12382|    0|
# |                                    0.0|    0|12436|
# +---------------------------------------+-----+-----+
# Random Forest
# +------------------------------+-----+----+
# |total_person_income_prediction|  1.0| 0.0|
# +------------------------------+-----+----+
# |                           1.0|11437| 945|
# |                           0.0| 3168|9268|
# +------------------------------+-----+----+
# Area Under ROC Curve: 0.918393627481
# Area Under Precision-Recall Curve: 0.908132474914
# Precision:
# 0.783087983567

# %% [markdown]
# The Random Forest model is now properly making more predictions instead of classifying everything in the same category all the time...

# %% [markdown]
# #### Cross-Validation

# %% [markdown]
# To avoid overfitting and have a more objective view of our model performances, we can implement a <a href="https://en.wikipedia.org/wiki/Cross-validation_(statistics)#k-fold_cross-validation">cross-validation</a> where we split our training data into multiple training and evaluation partitions.

# %%
# FIXME

# %% [markdown]
# ## Evaluation

# %% [markdown]
# * Apply your model to the test file and measure its real performance on it (same method as above).

# %%
measurePerformance(testData, firstModel)
measurePerformance(testData, secondModel)
# Out:
# Perfect Model
# +---------------------------------------+----+-----+
# |total_person_income_total_person_income| 1.0|  0.0|
# +---------------------------------------+----+-----+
# |                                    1.0|6186|    0|
# |                                    0.0|   0|93576|
# +---------------------------------------+----+-----+
# Random Forest
# +------------------------------+-----+---+
# |total_person_income_prediction|  0.0|1.0|
# +------------------------------+-----+---+
# |                           1.0| 6186|  0|
# |                           0.0|93576|  0|
# +------------------------------+-----+---+
# Area Under ROC Curve: 0.925770507246
# Area Under Precision-Recall Curve: 0.523264748566
# Precision:
# 0.0
#
# Perfect Model
# +---------------------------------------+----+-----+
# |total_person_income_total_person_income| 1.0|  0.0|
# +---------------------------------------+----+-----+
# |                                    1.0|6186|    0|
# |                                    0.0|   0|93576|
# +---------------------------------------+----+-----+
# Random Forest
# +------------------------------+-----+-----+
# |total_person_income_prediction|  1.0|  0.0|
# +------------------------------+-----+-----+
# |                           1.0| 5697|  489|
# |                           0.0|24402|69174|
# +------------------------------+-----+-----+
# Area Under ROC Curve: 0.915858869302
# Area Under Precision-Recall Curve: 0.482029109184
# Precision:
# 0.189275391209
# RandomForestClassificationModel (uid=rfc_b5c7fc0672f4) with 50 trees

# %% [markdown]
# Fine-tune the evaluation function to reflect some imaginary business cost of misclassifications instead...
#
# This is only an example to show that we should adapt this evaluation to the business use case. It is also an effective way to communicate the results back to non-technical audience.

# %%
def measureBusinessPerformance(data, model = None):
    if model == None:
        model = trainRandomForest(data)
    predictions = model.transform(data)
    confusionMat = predictions.crosstab(targetColumn, "prediction")
    if "1.0" in confusionMat.columns:
        confusionMat.show()
    else:
        confusionMat.withColumn("1.0", lit(0)).show()

    tp, fp, tn, fn = getConfusionMatrixCells(confusionMat)
    print "We offered a $50 gift to", int(tp), "customers that might be interested in a luxury saving account, avg ROI is $100"
    print "We offered a $50 gift to", int(fp), "customers that were not interested and declined the offer"
    print int(tn + fn), "customers were not contacted and they never purchased our banking services"
    print "Total marketing investment was: $" + str((tp + fp) * 50)
    print "ROI: $" + str( (tp * 100) + 
                         (fp * -50) +
                         (tn *   0) + 
                         (fn *   0) )
    return model

measureBusinessPerformance(testData, firstModel)
measureBusinessPerformance(testData, secondModel)
# Out:
# +------------------------------+-----+---+
# |total_person_income_prediction|  0.0|1.0|
# +------------------------------+-----+---+
# |                           1.0| 6186|  0|
# |                           0.0|93576|  0|
# +------------------------------+-----+---+
#
# We offered a $50 gift to 0 customers that might be interested in a luxury saving account, avg ROI is $100
# We offered a $50 gift to 0 customers that were not interested and declined the offer
# 99762 customers were not contacted and they never purchased our banking services
# Total marketing investment was: $0.0
# ROI: $0.0
# +------------------------------+-----+-----+
# |total_person_income_prediction|  1.0|  0.0|
# +------------------------------+-----+-----+
# |                           1.0| 5697|  489|
# |                           0.0|24402|69174|
# +------------------------------+-----+-----+
# We offered a $50 gift to
#  5697 customers that might be interested in a luxury saving account, avg ROI is $100
# We offered a $50 gift to 24402 customers that were not interested and declined the offer
# 69663 customers were not contacted and they never purchased our banking services
# Total marketing investment was: $1504950
# ROI: $-650400
# RandomForestClassificationModel (uid=rfc_b5c7fc0672f4) with 50 trees

# %% [markdown]
# If we were to roll out that model, we would lose money!
#
# Let's try to learn more about people not having more than $50000 so we make less costly mistakes...
#
# We can do this by rebalancing the dataset but give more importance to the label 0.0 by providing 3 times more data.
# (note that we shouldn't use the testData to figure what the right parameters are but use the cross validation of train data instead)

# %%
sample2TrainData = downSample(trainData, 3.0)
sample2TrainData.groupBy(targetColumn).count().show()
thirdModel = measurePerformance(sample2TrainData)
measurePerformance(testData, thirdModel)
# Out:
# +-------------------+-----+
# |total_person_income|count|
# +-------------------+-----+
# |                1.0|12382|
# |                0.0|36961|
# +-------------------+-----+
#
#
# Perfect Model
# +---------------------------------------+-----+-----+
# |total_person_income_total_person_income|  1.0|  0.0|
# +---------------------------------------+-----+-----+
# |                                    1.0|12382|    0|
# |                                    0.0|    0|36961|
# +---------------------------------------+-----+-----+
# Random Forest
# +------------------------------+----+-----+
# |total_person_income_prediction| 1.0|  0.0|
# +------------------------------+----+-----+
# |                           1.0|6447| 5935|
# |                           0.0|1347|35614|
# +------------------------------+----+-----+
# Area Under ROC Curve: 0.920770152543
# Area Under Precision-Recall Curve: 0.799243224272
# Precision:
# 0.827174749808
#
# Perfect Model
# +---------------------------------------+----+-----+
# |total_person_income_total_person_income| 1.0|  0.0|
# +---------------------------------------+----+-----+
# |                                    1.0|6186|    0|
# |                                    0.0|   0|93576|
# +---------------------------------------+----+-----+
# Random Forest
# +------------------------------+----+-----+
# |total_person_income_prediction| 1.0|  0.0|
# +------------------------------+----+-----+
# |                           1.0|3205| 2981|
# |                           0.0|3382|90194|
# +------------------------------+----+-----+
# Area Under ROC Curve: 0.920773741494
# Area Under Precision-Recall Curve: 0.515857856037
# Precision:
# 0.486564445119
# RandomForestClassificationModel (uid=rfc_3e4fd267883c) with 50 trees

# %%
measureBusinessPerformance(testData, thirdModel)
# Out:
# +------------------------------+----+-----+
# |total_person_income_prediction| 1.0|  0.0|
# +------------------------------+----+-----+
# |                           1.0|3205| 2981|
# |                           0.0|3382|90194|
# +------------------------------+----+-----+
#
# We offered a $50 gift to
#  3205 customers that might be interested in a luxury saving account, avg ROI is $100
# We offered a $50 gift to 3382 customers that were not interested and declined the offer
# 93175 customers were not contacted and they never purchased our banking services
# Total marketing investment was: $329350
# ROI: $151400
# RandomForestClassificationModel (uid=rfc_3e4fd267883c) with 50 trees

# %% [markdown]
# Of course, this is far from being the best model (I even picked some parameters randomly) but with more time to work on this exercise, we can iterate on and on through the CRISP-DM process to bring the evaluation function up to a satisfactory point where we can decide to deploy it into some "production" environment.
#
# My point here is that I wanted to show a base pipeline that is quickly built in few hours of work (in this context of interview exercise) rather than a "perfect" solution handling all the data aspects in order to get the best score out of this. This is best described in this article: http://www.techrepublic.com/article/start-tackling-data-science-inefficiencies-by-properly-defining-waste/
#
# However here are some ideas of aspects to work on to improve even more the predictions:

# %% [markdown]
# #### Resampling: Up sampling (SMOTE?)

# %% [markdown]
# Instead of throwing away data, we can synthetize or duplicate the rows from minority class instead to rebalance the dataset.

# %%
# FIXME

# %% [markdown]
# #### Rescaling

# %% [markdown]
# Not necessary for Random Forest but might be useful for other modeling algorithms

# %%
from sklearn.preprocessing import scale

# FIXME

# %% [markdown]
# #### Binning

# %% [markdown]
# Combine variables into bins based on <a href="http://www.listendata.com/2015/03/weight-of-evidence-woe-and-information.html">Weight Of Evidence</a> while increasing <a href="http://ucanalytics.com/blogs/information-value-and-weight-of-evidencebanking-case/">Information Value</a>
#
# #### Grouping Categorical Nominal characteristic:
#
# 1. For each Categorical Nominal variable, we start with one value per bin. So if we have N possible values, we have N bins.
# 2. We compute the Information Value.
# 3. Then we try every combinations of two bins and simulate a merge to recompute the new Information Value if they were grouped together.
# 4. We pick the pair of bins that provides the biggest change to Information Value between step 2 and 3 and we apply the merge
# 5. We reiterate with step 2 until we can't find any pairs that increase the Information Value anymore.
#
# #### Grouping Binary characteristic:
#
# Binary characteristics contains by definition only 2 potential values, therefore, no further grouping is possible.
#
# #### Grouping Categorical Ordinal and Numerical Continuous characteristics:
#
# 0. We start by transforming each value into an interval tuple with a lower and upper bound
# 1. For each Categorical Ordinal variable, we start with one value per bin. So if we have N possible values, we have N bins.
# 2. We compute the Information Value.
# 3. Then we try every combinations of two adjacent bins (the bin at index i and index i + 1) and simulate a merge to recompute the new Information Value if they were grouped together so that we produce a range of values. Grouping two bins results into taking the lower bound of the first bin and the upper bound of the second bin to produce the merged bin.
# 4. We pick the pair of bins that provides the biggest change to Information Value between step 2 and 3 and we apply the merge
# 5. We reiterate with step 2 until we can't find any pairs that increase the Information Value anymore.
#
# Note that with ordinal value, we make sure to merge only adjacent values. we are simply growing the intervals when possible without skipping values.

# %%
# FIXME

# %% [markdown]
# #### Parameter Optimization - fine tuning

# %%
# FIXME

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# <i>Coming up with features is difficult, time-consuming, requires expert knowledge. "Applied machine learning" is basically feature engineering.</i>
#
# — Andrew Ng

# %%
# FIXME
